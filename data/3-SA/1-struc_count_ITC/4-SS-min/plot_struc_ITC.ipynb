# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

csvname = 'struc_count_ITC.csv'
df = pd.read_csv(csvname, index_col=0)

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
colors = cm.rainbow(np.linspace(0, 1, 10))

for i, value in enumerate(df['L'].unique()):
    subset = df[df['L'] == value]
    ax.scatter(subset['struc_count'], subset['ITC'], subset['L'], c=np.array(colors[i]).reshape(1,-1), label=r'$\mathit{L}$ = ' + str(value))

ax.set_xlabel('Search counts', fontsize=14, fontweight='bold', labelpad=10)
ax.set_ylabel('σ (MW/m²K)', fontsize=14, fontweight='bold', labelpad=10)
ax.set_zlabel(r'$\mathit{L}$', fontsize=14, fontweight='bold', labelpad=10)

ax.xaxis.pane.set_edgecolor('black')
ax.yaxis.pane.set_edgecolor('black')
ax.zaxis.pane.set_edgecolor('black')

ax.xaxis.pane.set_linewidth(3)
ax.yaxis.pane.set_linewidth(3)
ax.zaxis.pane.set_linewidth(3)

x_axis = ax.get_xaxis()
y_axis = ax.get_yaxis()
z_axis = ax.get_zaxis()

for label in x_axis.get_ticklabels():
    label.set_fontweight('bold')

for label in y_axis.get_ticklabels():
    label.set_fontweight('bold')

for label in z_axis.get_ticklabels():
    label.set_fontweight('bold')

ax.view_init(elev=20, azim=225)
plt.savefig('L.jpg', dpi=800, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
colors = cm.rainbow(np.linspace(0, 1, 10))

for i, value in enumerate(df['max_stay_counter'].unique()):
    subset = df[df['max_stay_counter'] == value]
    ax.scatter(subset['struc_count'], subset['ITC'], subset['max_stay_counter'], c=np.array(colors[i]).reshape(1,-1), label=r'$\mathit{k}_{\mathrm{max}}$ = ' + str(value))

ax.set_xlabel('Search counts', fontsize=14, fontweight='bold', labelpad=10)
ax.set_ylabel('σ (MW/m²K)', fontsize=14, fontweight='bold', labelpad=10)
ax.set_zlabel(r'$\mathit{k}_{\mathrm{max}}$', fontsize=14, fontweight='bold', labelpad=10)

ax.xaxis.pane.set_edgecolor('black')
ax.yaxis.pane.set_edgecolor('black')
ax.zaxis.pane.set_edgecolor('black')

ax.xaxis.pane.set_linewidth(3)
ax.yaxis.pane.set_linewidth(3)
ax.zaxis.pane.set_linewidth(3)

x_axis = ax.get_xaxis()
y_axis = ax.get_yaxis()
z_axis = ax.get_zaxis()

for label in x_axis.get_ticklabels():
    label.set_fontweight('bold')

for label in y_axis.get_ticklabels():
    label.set_fontweight('bold')

for label in z_axis.get_ticklabels():
    label.set_fontweight('bold')

ax.view_init(elev=20, azim=225)
plt.savefig('k.jpg', dpi=800, bbox_inches='tight')
